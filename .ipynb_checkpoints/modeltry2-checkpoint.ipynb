# %%
import findspark
findspark.init()
from pyspark import SparkContext
sc=SparkContext()
sc
# Out:
# <SparkContext master=yarn appName=pyspark-shell>

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ip-172-31-59-101.ec2.internal:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Data Preprocessing

# %%
data2019 = spark.read.option("header", "true").csv("s3://open-data-noaa/cleaneddata/*.csv")

# %%
data2019.describe().toPandas().transpose()
# Out:
#                   0                     1                     2  \
# summary       count                  mean                stddev
# station    10667288  6.402539715675161E10  2.202353316815244E10
# date       10667288                  None                  None
# latitude   10667288     39.64761048765711    13.332834233537914
# longitude  10667288    -73.28299134005056     59.99891615573195
# elevation  10667288    330.46461744734705     473.1285403333939
# wind       10667288    3.4802102746319687    2.6772880489647335
# cig        10667288    12343.769747849688    10261.993956500071
# vis        10667288     15589.56656668499     7608.232470454823
# temp       10667288     12.83764749765804     11.75649100581275
# dew        10667288     6.821608885032209    11.075705669613196
# slp        10667288    1015.0402356437745     8.379028376011338
# liquid     10655812   0.15379245239057768    1.0674104987921877
# liqhr      10667288     2.609154547997579    19.345654313026227
# month      10667288     6.471539251588595    3.4673744741949495
#
#                              3                    4
# summary                    min                  max
# station            01001099999          A0735400132
# date       2019-01-01T00:00:00  2020-01-01T10:51:00
# latitude                -0.083             9.993861
# longitude            -0.006439             99.96667
# elevation                 -1.0                999.1
# wind                       0.0                  9.9
# cig                        0.0                990.0
# vis                        0.0               9999.0
# temp                      -0.1                  9.9
# dew                       -0.1                  9.9
# slp                     1000.0                999.9
# liquid                     0.0                 99.0
# liqhr                      0.0               9999.0
# month                        1                    9

# %%
data=data2019.groupBy("station").agg({'latitude':'avg', 'longitude':'avg','elevation':'avg', 'wind':'avg', 'cig':'avg', 'vis':'avg', 'temp':'avg', 'dew':'avg', 'slp':'avg', 'liquid':'avg'})

# %%
data.printSchema()
# Out:
# root
#  |-- station: string (nullable = true)
#  |-- avg(liquid): double (nullable = true)
#  |-- avg(latitude): double (nullable = true)
#  |-- avg(dew): double (nullable = true)
#  |-- avg(vis): double (nullable = true)
#  |-- avg(longitude): double (nullable = true)
#  |-- avg(wind): double (nullable = true)
#  |-- avg(elevation): double (nullable = true)
#  |-- avg(temp): double (nullable = true)
#  |-- avg(cig): double (nullable = true)
#  |-- avg(slp): double (nullable = true)

# %%
from pyspark.sql import functions
data = data.select(*(functions.col(col).cast("float").alias(col) for col in data.columns))

# %%
data.printSchema()
# Out:
# root
#  |-- station: float (nullable = true)
#  |-- avg(liquid): float (nullable = true)
#  |-- avg(latitude): float (nullable = true)
#  |-- avg(dew): float (nullable = true)
#  |-- avg(vis): float (nullable = true)
#  |-- avg(longitude): float (nullable = true)
#  |-- avg(wind): float (nullable = true)
#  |-- avg(elevation): float (nullable = true)
#  |-- avg(temp): float (nullable = true)
#  |-- avg(cig): float (nullable = true)
#  |-- avg(slp): float (nullable = true)

# %%
data = data.withColumnRenamed("avg(latitude)","latitude")
data = data.withColumnRenamed("avg(liquid)","liquid")
data = data.withColumnRenamed("avg(dew)","dew")
data = data.withColumnRenamed("avg(vis)","vis")
data = data.withColumnRenamed("avg(longitude)","longitude")
data = data.withColumnRenamed("avg(wind)","wind")
data = data.withColumnRenamed("avg(elevation)","elevation")
data = data.withColumnRenamed("avg(temp)","temp")
data = data.withColumnRenamed("avg(cig)","cig")
data = data.withColumnRenamed("avg(slp)","slp")

# %%
data=data.dropna()

# %%
data=data.drop('station')

# %%
data.printSchema()
# Out:
# root
#  |-- liquid: float (nullable = true)
#  |-- latitude: float (nullable = true)
#  |-- dew: float (nullable = true)
#  |-- vis: float (nullable = true)
#  |-- longitude: float (nullable = true)
#  |-- wind: float (nullable = true)
#  |-- elevation: float (nullable = true)
#  |-- temp: float (nullable = true)
#  |-- cig: float (nullable = true)
#  |-- slp: float (nullable = true)

# %%
data.count()
# Out:
# 6707

# %%
data.describe().toPandas().transpose()
# Out:
#                0                   1                   2           3  \
# summary    count                mean              stddev         min
# liquid      6707  0.3797537762401148  1.2088738255717435         0.0
# latitude    6707   32.65529795006569   25.30436176238515       -78.8
# dew         6707   8.864341877460046   9.952693092167118  -31.321428
# vis         6707  16171.996371865149  10367.568175214878         0.0
# longitude   6707  14.618832663720896   85.28433171298626  -179.98334
# wind        6707   3.047421344612985  1.7324453717422974         0.0
# elevation   6707  296.35709708285646  494.94474224801473      -999.9
# temp        6707   13.77539589372258   9.688231396767177  -25.013725
# cig         6707  11613.875369421608   7284.168907227307        30.0
# slp         6707    1013.30189947558   5.304069463657375       951.5
#
#                    4
# summary          max
# liquid          63.5
# latitude   81.166664
# dew             27.9
# vis         71615.66
# longitude     179.75
# wind       19.581396
# elevation     4701.0
# temp            37.6
# cig          22000.0
# slp           1084.9

# %% [markdown]
# # Model-Ridge\Lasso\Decision Tree\Gradient-boosted tree

# %%
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.evaluation import BinaryClassificationEvaluator

# %%
from pandas.plotting import scatter_matrix

numeric_features = [t[0] for t in data.dtypes if t[1] == 'float' ]
sampled_data = data.select(numeric_features).sample(False, 0.8).toPandas()
axs = scatter_matrix(sampled_data, figsize=(10, 10))
n = len(sampled_data.columns)
for i in range(n):
    v = axs[i, 0]
    v.yaxis.label.set_rotation(0)
    v.yaxis.label.set_ha('right')
    v.set_yticks(())
    h = axs[n-1, i]
    h.xaxis.label.set_rotation(90)
    h.set_xticks(())

# %%
import six
for i in data.columns:
    if not( isinstance(data.select(i).take(1)[0][0], six.string_types)):
        print( "Correlation to temp for ", i, data.stat.corr('temp',i))
# Out:
# Correlation to temp for  liquid 0.13367557022544582
# Correlation to temp for  latitude -0.6010993211002451
# Correlation to temp for  dew 0.9297631385954203
# Correlation to temp for  vis -0.2924514060520924
# Correlation to temp for  longitude 0.09692998604781519
# Correlation to temp for  wind -0.23392199279050369
# Correlation to temp for  elevation -0.17445827638840694
# Correlation to temp for  temp 1.0
# Correlation to temp for  cig 0.0386774552871484
# Correlation to temp for  slp -0.18439676048942177

# %% [markdown]
# ### Feature and Label Selection

# %%
features=['liquid', 'latitude', 'dew', 'vis', 'longitude', 'wind', 'elevation', 'cig', 'slp']

# %%
from pyspark.ml.feature import VectorAssembler
vectorAssembler = VectorAssembler(inputCols = ['liquid', 'latitude', 'dew', 'vis', 'longitude', 'wind', 'elevation', 'cig', 'slp'], outputCol = 'features')

# %%
v_df = vectorAssembler.transform(data)
v_df = v_df.select(['features', 'temp'])

# %%
v_df.show(3)
# Out:
# +--------------------+---------+
# |            features|     temp|
# +--------------------+---------+
# |[0.11067678779363...|17.566782|
# |[0.05067010968923...|11.252631|
# |[0.01196296326816...|18.086666|
# +--------------------+---------+
# only showing top 3 rows

# %% [markdown]
# ### Train/Test

# %%
splits = v_df.randomSplit([0.7, 0.3])
train_df = splits[0]
test_df = splits[1]

# %% [markdown]
# ## Model1: Ridge Regression

# %%
from pyspark.ml.regression import LinearRegression

# %%
Ridge= LinearRegression(featuresCol='features', labelCol='temp', regParam=0.5, elasticNetParam=0)
Ridge_model = Ridge.fit(train_df)

print("Coefficients: " + str(Ridge_model.coefficients))
print("Intercept: " + str(Ridge_model.intercept))
# Out:
# Coefficients: [-0.13138660179065426,-0.02742148524499612,0.8661507962451893,-8.383708745582011e-06,-0.0004944688828465109,0.1377845576291047,0.001603654289718254,0.00020658845344598866,-0.03128023046453908]
# Intercept: 35.57874288153557

# %%
import numpy as np
[features[i] for i in np.nonzero(Ridge_model.coefficients)[0]]
# Out:
# ['liquid',
#  'latitude',
#  'dew',
#  'vis',
#  'longitude',
#  'wind',
#  'elevation',
#  'cig',
#  'slp']

# %%
ridge_predictions = Ridge_model.transform(test_df)

# %%
evaluator_ridge = RegressionEvaluator(labelCol='temp')

# %%
evaluator_ridge.evaluate(ridge_predictions, {evaluator_ridge.metricName: "r2"})
# Out:
# 0.9050353445793253

# %%
ridge_evaluator = RegressionEvaluator(
    labelCol="temp", predictionCol="prediction", metricName="rmse")
rmse1 = ridge_evaluator.evaluate(ridge_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse1)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.99368

# %% [markdown]
# ## Lasso Regression

# %%
Lasso= LinearRegression(featuresCol='features', labelCol='temp', regParam=0.5, elasticNetParam=1)
Lasso_model = Lasso.fit(train_df)

print("Coefficients: " + str(Lasso_model.coefficients))
print("Intercept: " + str(Lasso_model.intercept))
# Out:
# Coefficients: [0.0,-0.008508259947726532,0.8660208044079444,0.0,0.0,0.0,0.0006862892284319423,0.00014799913697991106,0.0]
# Intercept: 4.4495220859068025

# %%
[features[i] for i in np.nonzero(Lasso_model.coefficients)[0]]
# Out:
# ['latitude', 'dew', 'elevation', 'cig']

# %%
lasso_predictions = Lasso_model.transform(test_df)

# %%
evaluator_lasso = RegressionEvaluator(labelCol='temp')

# %%
evaluator_lasso.evaluate(lasso_predictions, {evaluator_lasso.metricName: "r2"})
# Out:
# 0.8971312687878917

# %%
lasso_evaluator = RegressionEvaluator(
    labelCol="temp", predictionCol="prediction", metricName="rmse")
rmse2 = lasso_evaluator.evaluate(lasso_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse2)
# Out:
# Root Mean Squared Error (RMSE) on test data = 3.11577

# %% [markdown]
# ## Decision Tree

# %%
from pyspark.ml.regression import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor(featuresCol ='features', labelCol = 'temp')
dt_model = dt.fit(train_df)

# %%
dt_predictions = dt_model.transform(test_df)

# %%
evaluator_dt = RegressionEvaluator(labelCol='temp')

# %%
evaluator_dt.evaluate(dt_predictions, {evaluator_dt.metricName: "r2"})
# Out:
# 0.9048872513702393

# %%
dt_evaluator = RegressionEvaluator(
    labelCol="temp", predictionCol="prediction", metricName="rmse")
rmse3 = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse3)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.99601

# %%
dt_model.featureImportances
# Out:
# SparseVector(9, {0: 0.0132, 1: 0.0398, 2: 0.9211, 6: 0.0077, 7: 0.0158, 8: 0.0024})

# %%
from matplotlib import pyplot as plt 
x =  features
y =  dt_model.featureImportances 
plt.bar(x, y, align =  'center',color='g') 
plt.title('Bar graph') 
plt.ylabel('Y axis') 
plt.xlabel('X axis') 
plt.show()

# %% [markdown]
# ## Gradient-boosted tree regression

# %%
from pyspark.ml.regression import GBTRegressor
gbt = GBTRegressor(featuresCol = 'features', labelCol = 'temp', maxIter=10)
gbt_model = gbt.fit(train_df)

# %%
gbt_predictions = gbt_model.transform(test_df)

# %%
evaluator_gbt = RegressionEvaluator(labelCol='temp')

# %%
evaluator_gbt.evaluate(gbt_predictions, {evaluator_gbt.metricName: "r2"})
# Out:
# 0.9272543989837837

# %%
gbt_evaluator = RegressionEvaluator(
    labelCol="temp", predictionCol="prediction", metricName="rmse")
rmse4 = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse4)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.62016

# %%
sc.stop()
